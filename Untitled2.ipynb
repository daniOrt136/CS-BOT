# %%
import pyhdb
import datetime
from datetime import timedelta
import pandas as pd
from openpyxl.styles import Font, Color, PatternFill, Protection, Alignment, Border, Side
from openpyxl.worksheet.datavalidation import DataValidation
import os
import openpyxl as xl
DEBUG = False
from hdbcli import dbapi
connection = dbapi.connect(address="sapw1pdb00.dir.slb.com",port=30015, user="LABOT", password="kC-mcLArs8b3E")

#connection = pyhdb.connect(host="sapw1pdb00.dir.slb.com",port=30015, user="LABOT",password="kC-mcLArs8b3E")
cursor = connection.cursor()
query="SELECT EBELN AS PO_Num, EBELP AS PO_Line, UNSEZ, TXZ01 AS Description, NETWR AS Value_USD, NETWR_USD AS Value_USD, TO_CHAR(SLFDT,'MM/dd/yyyy') AS Initial_SPD, "
query= query + "TO_CHAR(EINDT,'MM/dd/yyyy') AS Current_SPD,VEND_NAME1 AS Supplier_Name, CDOC_USNM_NAME_TEXT_ITEM AS Assigned_Customer_Service_Agent,BEDNR AS Tracking_Number, "
query= query + "PLNT_NAME1 AS Plant_name,SOTX_TDLINE_F48 AS Action_ ,ERNAM AS PO_Creted_BY,ERNAM_1 AS PR_Created_By, MENGE, WERKS, BSART, PPRO_LIFN2_PI, UNSEZ, ZORG_SEG_LEVEL_2, MATNR, USNM_NAME_TEXT "
query= query + "FROM \"_SYS_BIC\".\"slb.bi.sup.sdi/SUP_STG_PO_END_TO_END_INTEGRATION\" "
query= query + "WHERE STG_CURRENT_FLAG=1 AND CM_QTY_DELIVER_LEFT <> 0 "
query= query + "AND BEDAT > '20221103' "

cursor.execute(query)
         
MyList=(cursor.fetchall())


df = pd.DataFrame(MyList)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4996/4047637410.py in <module>
#      26
#      27 df = pd.DataFrame(MyList)
# ---> 28 df[~pd.isna(df['2'])]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# KeyError: '2'

# %%
df[df[2]!='']
# Out:
#               0      1           2                                         3   \
# 1948  4581777373  00002        LGA2  BOX, SHIPPING: 18 FT 6 IN, L, STL, 375-~
# 1949  4581777373  00001        LGA2  BOX, SHIPPING: 12 FT 6 IN, L, STL, 375-~
# 1950  4581777507  00002        WTR3  MICRO CONTROLLER, PLUS+1 TYPE, PROGRAMM~
# 1951  4581777507  00001        WTR3  POTENTIOMETER, 200 OHMS,2.75 WATT, BUSHI
# 1952  4581777507  00003        WTR3  ANALOG LOAD CELL AMPLIFIER MODULE, SGA,~
# 1953  4581777380  00001  CSA1 Saudi          MEMO PO to cover AF of RM / SSSV
# 1954  4791398503  00001        CCM1            CROSSOVER,41XX[80],30 IN LONG,
# 1955  4791398503  00005        CCM1            CROSSOVER,41XX[80],30 IN LONG,
# 1956  4791398503  00006        CCM1  2.688 X 1.955 X 18 SEAL UNIT, 41XX (80)~
# 1957  4791398503  00002        CCM1            CROSSOVER,41XX[80],30 IN LONG,
# 1958  4791398503  00007        CCM1            CROSSOVER,41XX[80],30 IN LONG,
# 1959  4791398503  00003        CCM1            SLIDING SLEEVES,1.875/X NIPPLE
# 1960  4791398503  00004        CCM1            LANDING NIPPLE,1.875/XN,41XX[8
# 1961  4791398503  00008        CCM1            CROSSOVER,41XX[80],30 IN LONG,
# 1962  4791398503  00009        CCM1            CROSSOVER,41XX[80],33 IN LONG,
# 1973  4581777074  00022           1                  POWER SUPPLY;UNIVSL MODL
# 1974  4581777074  00019           1                  POWER SUPPLY;UNIVSL MODL
# 1975  4581777075  00007           1                  POWER SUPPLY;UNIVSL MODL
# 1976  4581777075  00006           1                  POWER SUPPLY;UNIVSL MODL
# 1984  4581777075  00004           1  PDIM-BD POWER DISTRIBUTION INTERFACE MO~
# 1985  4581777074  00010           1            MODULE:INTERFACE;DEPTH/TENSION
# 1986  4581777074  00012           1                MODULE:INTERFACE;TELEMETRY
# 1987  4581777075  00010           1                MODULE:INTERFACE;TELEMETRY
# 1988  4581777074  00013           1                MODULE:INTERFACE;TELEMETRY
# 1989  4581777075  00011           1                MODULE:INTERFACE;TELEMETRY
# 1990  4581777075  00012           1                   MCML-ED WIRELINE LAPTOP
# 1991  4581777074  00018           1  PDIM-BD POWER DISTRIBUTION INTERFACE MO~
# 1992  4581777074  00008           1  EWCD-ABD eWAFE COMMUNICATION DRAWER, Ro~
# 1993  4581777075  00001           1    KIT, PERIPHERALS FOR UPL-SS STANDALONE
# 1994  4581777074  00023           1                   MCML-ED WIRELINE LAPTOP
# 1995  4581777074  00003           1    KIT, PERIPHERALS FOR UPL-SS STANDALONE
# 1996  4581777074  00001           1  UPL-SS, UNIVERSAL PAYLOAD FOR STANDARD ~
# 1997  4581777075  00008           1  UPL-SS, UNIVERSAL PAYLOAD FOR STANDARD ~
# 1998  4581777075  00003           1  EWCD-ABD eWAFE COMMUNICATION DRAWER, Ro~
# 1999  4581777075  00005           1  PDIM-BD POWER DISTRIBUTION INTERFACE MO~
# 2000  4581777075  00009           1            MODULE:INTERFACE;DEPTH/TENSION
# 2001  4581777074  00015           1  PDIM-BD POWER DISTRIBUTION INTERFACE MO~
#
#             4         5           6     7                              8   \
# 1948   2219.84   2219.84  11/04/2022  None        Reda Production Systems
# 1949   1370.72   1370.72  11/04/2022  None        Reda Production Systems
# 1950    5475.4    5475.4  11/04/2022  None  FRANCE CONVEYANCE AND SURFACE
# 1951    358.12    358.12  11/04/2022  None  FRANCE CONVEYANCE AND SURFACE
# 1952   1595.96   1595.96  11/04/2022  None  FRANCE CONVEYANCE AND SURFACE
# 1953      4800      4800  03/31/2022  None       COMPLETIONS PRODUCT UNIT
# 1954   3890.58   2761.23  11/10/2022  None    COMPLETION PRODUCTS PTE LTD
# 1955    6175.8    4383.1  11/10/2022  None    COMPLETION PRODUCTS PTE LTD
# 1956   16779.6  11908.87  11/10/2022  None    COMPLETION PRODUCTS PTE LTD
# 1957   3780.03   2682.77  11/10/2022  None    COMPLETION PRODUCTS PTE LTD
# 1958   3890.58   2761.23  11/10/2022  None    COMPLETION PRODUCTS PTE LTD
# 1959  15182.19  10775.15  11/10/2022  None    COMPLETION PRODUCTS PTE LTD
# 1960   6128.48   4349.52  11/10/2022  None    COMPLETION PRODUCTS PTE LTD
# 1961   3780.03   2682.77  11/10/2022  None    COMPLETION PRODUCTS PTE LTD
# 1962   7428.52   5272.19  11/10/2022  None    COMPLETION PRODUCTS PTE LTD
# 1973     10712     10712  10/01/2023  None        Reda Production Systems
# 1974     10712     10712  10/01/2023  None        Reda Production Systems
# 1975     10712     10712  01/10/2023  None        Reda Production Systems
# 1976     10712     10712  01/10/2023  None        Reda Production Systems
# 1984  15992.22  15992.22  01/10/2023  None        Reda Production Systems
# 1985      5698      5698  10/01/2023  None        Reda Production Systems
# 1986      8734      8734  10/01/2023  None        Reda Production Systems
# 1987      8734      8734  01/10/2023  None        Reda Production Systems
# 1988      8734      8734  10/01/2023  None        Reda Production Systems
# 1989      8734      8734  01/10/2023  None        Reda Production Systems
# 1990    3430.4    3430.4  01/10/2023  None        Reda Production Systems
# 1991  15992.22  15992.22  10/01/2023  None        Reda Production Systems
# 1992   2753.88   2753.88  10/01/2023  None        Reda Production Systems
# 1993     19345     19345  01/10/2023  None        Reda Production Systems
# 1994    3430.4    3430.4  10/01/2023  None        Reda Production Systems
# 1995     19345     19345  10/01/2023  None        Reda Production Systems
# 1996    361000    361000  10/01/2023  None        Reda Production Systems
# 1997    361000    361000  01/10/2023  None        Reda Production Systems
# 1998   2753.88   2753.88  01/10/2023  None        Reda Production Systems
# 1999  15992.22  15992.22  01/10/2023  None        Reda Production Systems
# 2000      5698      5698  01/10/2023  None        Reda Production Systems
# 2001  15992.22  15992.22  10/01/2023  None        Reda Production Systems
#
#             9   ...        13            14  15    16    17          18  \
# 1948  BATCH-SU  ...  01851153      01851153   4  9510  ZICP      IVSG03
# 1949  BATCH-SU  ...  01851153      01851153   4  9510  ZICP      IVSG03
# 1950  BATCH-SU  ...  BATCH-SU      05839667   4  9510  ZICP      IVFR03
# 1951  BATCH-SU  ...  BATCH-SU      05839667   4  9510  ZICP      IVFR03
# 1952  BATCH-SU  ...  BATCH-SU      05839667   4  9510  ZICP      IVFR03
# 1953  BATCH-SU  ...  01851153      80038953   1  9512   ZNB      IVCN06
# 1954  BATCH-SU  ...  05839667  SYS-SWP-OAUT   3  9510   ZNB  1000000475
# 1955  BATCH-SU  ...  05839667  SYS-SWP-OAUT   3  9510   ZNB  1000000475
# 1956  BATCH-SU  ...  05839667  SYS-SWP-OAUT  20  9510   ZNB  1000000475
# 1957  BATCH-SU  ...  05839667  SYS-SWP-OAUT   3  9510   ZNB  1000000475
# 1958  BATCH-SU  ...  05839667  SYS-SWP-OAUT   3  9510   ZNB  1000000475
# 1959  BATCH-SU  ...  05839667  SYS-SWP-OAUT   3  9510   ZNB  1000000475
# 1960  BATCH-SU  ...  05839667  SYS-SWP-OAUT   2  9510   ZNB  1000000475
# 1961  BATCH-SU  ...  05839667  SYS-SWP-OAUT   3  9510   ZNB  1000000475
# 1962  BATCH-SU  ...  05839667  SYS-SWP-OAUT   4  9510   ZNB  1000000475
# 1973      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1974      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1975      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1976      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1984      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1985      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1986      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1987      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1988      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1989      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1990      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1991      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1992      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1993      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1994      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1995      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1996      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1997      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1998      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 1999      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 2000      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
# 2001      None  ...  BATCH-SU          None   1  9154  ZICP      IVSG03
#
#               19       20         21                  22
# 1948        LGA2    PMGBS    0680793  Mary-Ann Fernandez
# 1949        LGA2    PMGBS    0680769  Mary-Ann Fernandez
# 1950        WTR3    PMGBS  101651566            BATCH-SU
# 1951        WTR3    PMGBS    E053238            BATCH-SU
# 1952        WTR3    PMGBS  100379884            BATCH-SU
# 1953  CSA1 Saudi     WPRS  EF-SV-CPU  Mary-Ann Fernandez
# 1954        CCM1    PMGBS  104389094          Maya Rehan
# 1955        CCM1    PMGBS  104422612          Maya Rehan
# 1956        CCM1    PMGBS  103387728          Maya Rehan
# 1957        CCM1    PMGBS  104389095          Maya Rehan
# 1958        CCM1    PMGBS  104389093          Maya Rehan
# 1959        CCM1    PMGBS  104422610          Maya Rehan
# 1960        CCM1    PMGBS  104422611          Maya Rehan
# 1961        CCM1    PMGBS  104389094          Maya Rehan
# 1962        CCM1    PMGBS  104422609          Maya Rehan
# 1973           1           101109150            BATCH-SU
# 1974           1           101109150            BATCH-SU
# 1975           1           101109150            BATCH-SU
# 1976           1           101109150            BATCH-SU
# 1984           1           101387426            BATCH-SU
# 1985           1           100983555            BATCH-SU
# 1986           1           101119938            BATCH-SU
# 1987           1           101119938            BATCH-SU
# 1988           1           101119938            BATCH-SU
# 1989           1           101119938            BATCH-SU
# 1990           1  DLV_RPF  104389359            BATCH-SU
# 1991           1           101387426            BATCH-SU
# 1992           1           104233858            BATCH-SU
# 1993           1           102041243            BATCH-SU
# 1994           1  DLV_RPF  104389359            BATCH-SU
# 1995           1           102041243            BATCH-SU
# 1996           1           101635000            BATCH-SU
# 1997           1           101635000            BATCH-SU
# 1998           1           104233858            BATCH-SU
# 1999           1           101387426            BATCH-SU
# 2000           1           100983555            BATCH-SU
# 2001           1           101387426            BATCH-SU
#
# [37 rows x 23 columns]

# %%
df[2][1]
# Out:
# ''

# %%
STG_SUP_SDI_DISTRIBUTION_REPORT
