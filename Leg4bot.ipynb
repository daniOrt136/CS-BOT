# %%
#import hdbcli
import pyhdb
import datetime
from datetime import timedelta
import pandas as pd
from openpyxl.styles import Font, Color, PatternFill, Protection, Alignment, Border, Side
from openpyxl.worksheet.datavalidation import DataValidation
import os
import openpyxl as xl
DEBUG = False

## English template design function

def excel_manipulation(ruta):
    wb = xl.load_workbook(ruta)
    ws = wb.active
    
    global temp_df
    l = len(temp_df)+1

    #Changing Zoom to a sheet
    ws.sheet_view.zoomScale = 100

    #Defining the border style
    thin_border = Border(left=Side(style='thin'),
                         right=Side(style='thin'),
                         top=Side(style='thin'),
                         bottom=Side(style='thin')                    
                        )

    #applying borders to all table
    for row in ws.iter_rows():
            for cell in row:
                cell.alignment = Alignment(wrapText=False)
                cell.font = Font(name='Calibri', size=11)
                cell.border = thin_border
                cell.alignment = Alignment(vertical='center', horizontal='center')
    #modifing the header style
    for i in ws[1]:
        i.font = Font(color="00000000", name='Calibri', size=12, bold = True)

    a1 = ws['A1']
    b1 = ws['B1']
    c1 = ws['C1']
    d1 = ws['D1']
    e1 = ws['E1']
    f1 = ws['F1']
    g1 = ws['G1']
    h1 = ws['H1']
    i1 = ws['I1']
    j1 = ws['J1']
    k1 = ws['K1']
    l1 = ws['L1']
    m1 = ws['M1']
    n1 = ws['N1']
    o1 = ws['O1']
    p1 = ws['P1']
    q1 = ws['Q1']
    r1 = ws['R1']
    
    #Clean blue
    a1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    b1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    c1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    d1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    e1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    f1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    g1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    h1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    i1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    j1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    k1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    m1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    q1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")

    
    #Green
    l1.fill = PatternFill(fgColor="0079da4c", fill_type = "solid")
    n1.fill = PatternFill(fgColor="0079da4c", fill_type = "solid")
    o1.fill = PatternFill(fgColor="0079da4c", fill_type = "solid")
    p1.fill = PatternFill(fgColor="0079da4c", fill_type = "solid")
    
    #fit to the width
    col = ws.column_dimensions['A'].width = 11
    col = ws.column_dimensions['B'].width = 8
    col = ws.column_dimensions['C'].width = 10
    col = ws.column_dimensions['D'].width = 6
    col = ws.column_dimensions['E'].width = 14
    col = ws.column_dimensions['F'].width = 25
    col = ws.column_dimensions['G'].width = 42
    col = ws.column_dimensions['H'].width = 16
    col = ws.column_dimensions['I'].width = 34
    col = ws.column_dimensions['J'].width = 23
    col = ws.column_dimensions['K'].width = 10
    col = ws.column_dimensions['L'].width = 47
    col = ws.column_dimensions['M'].width = 57
    col = ws.column_dimensions['N'].width = 44
    col = ws.column_dimensions['O'].width = 28
    col = ws.column_dimensions['P'].width = 22
    col = ws.column_dimensions['Q'].width = 17

    
    #Heigh of the header row
    ws.row_dimensions[1].height = 30
    
    #Autocomplete formul writing the formula in each cell
    starter = 0
    i = 1
    for cell in ws['M']:
        if starter == 0:
            pass
        else:
            #Adding suggestions based on the response
            exc_formula = '=IF(L{}="Line Item Delivered-Shipped (Complete Shipment)","Please provide Shipping details / Tracking # / POD in column Q",IF(L{}="Original Delivery Date Remains","Please Provide comments if they are necessary in column O",IF(L{}="New Delivery Date","Please Provide new date in column P",IF(L{}="PO Not Received","Please Provide comments if they are necessary in column O",IF(L{}="Payment Issues","Please Provide reason why in column O",IF(L{}="Line Item Needs to be Cancelled","Please Provide reason why in column O",IF(L{}="Line Item Needs to be Modified","Please Specify changes needed in column O",IF(L{}="Material Ready for Pick Up","Please send Delivery Documents Packing Slip / Commercial Invoice / Material Safety Data",""))))))))'.format(i,i,i,i,i,i,i,i)
            cell.value = '{}'.format(exc_formula) 
        starter+=1
        i+=1
    
    #Dropdown List
    dv = DataValidation(type="list", formula1='"Line Item Delivered-Shipped (Complete Shipment), Original Delivery Date Remains, New Delivery Date, PO Not Received, Payment Issues, Line Item Needs to be Cancelled, Line Item Needs to be Modified, Material Ready for Pick Up"', allow_blank=False)
    ws.add_data_validation(dv)
    
    #Adding dropdown list to the cell
    dv.add('L2:L{}'.format(l))
    
    #Protecting the sheet
    #ws.protection.sheet = True
    #ws.protection.password = 'CS2021'
    
    #Cells to unlock
    c_unlock = ['M', 'O', 'P', 'Q', 'R']
    
    #Unlocking needed cells
    for col in c_unlock:
        starter = 0
        for cell in ws[col]:
            if starter == 0:
                pass
            else:
                cell.protection = Protection(locked=False)
            starter+=1
    
    #Priority coloration
    starter = 0
    for cell in ws['K']:
        if starter == 0:
            pass
        else:
            if cell.value == 'Medium':
                #Yellow
                cell.fill = PatternFill(fgColor="00ffee97", fill_type = "solid")
                cell.font = Font(color="00a55127")
                
            elif cell.value == 'High':
                #Red
                cell.fill = PatternFill(fgColor="00ffc1cc", fill_type = "solid")
                cell.font = Font(color="00aa004f")
                
            elif cell.value == 'Low':
                #Red
                cell.fill = PatternFill(fgColor="00baffce", fill_type = "solid")
                cell.font = Font(color="00006800")
        starter+=1
    
    wb.save(filename=ruta)

## Spanish template design function

def excel_manipulation_es(ruta):
    wb = xl.load_workbook(ruta)
    ws = wb.active
    
    global temp_df
    l = len(temp_df)+1

    #Changing Zoom to a sheet
    ws.sheet_view.zoomScale = 100

    #Defining the border style
    thin_border = Border(left=Side(style='thin'),
                         right=Side(style='thin'),
                         top=Side(style='thin'),
                         bottom=Side(style='thin')                    
                        )

    #applying borders to all table
    for row in ws.iter_rows():
            for cell in row:
                cell.alignment = Alignment(wrapText=False)
                cell.font = Font(name='Calibri', size=11)
                cell.border = thin_border
                cell.alignment = Alignment(vertical='center', horizontal='center')
    #modifing the header style
    for i in ws[1]:
        i.font = Font(color="00000000", name='Calibri', size=12, bold = True)

    a1 = ws['A1']
    b1 = ws['B1']
    c1 = ws['C1']
    d1 = ws['D1']
    e1 = ws['E1']
    f1 = ws['F1']
    g1 = ws['G1']
    h1 = ws['H1']
    i1 = ws['I1']
    j1 = ws['J1']
    k1 = ws['K1']
    l1 = ws['L1']
    m1 = ws['M1']
    n1 = ws['N1']
    o1 = ws['O1']
    p1 = ws['P1']
    q1 = ws['Q1']
    r1 = ws['R1']
    
    #Clean blue
    a1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    b1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    c1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    d1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    e1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    f1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    g1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    h1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    i1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    j1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    k1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    l1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    n1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    r1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    
    #Green
    m1.fill = PatternFill(fgColor="0079da4c", fill_type = "solid")
    o1.fill = PatternFill(fgColor="0079da4c", fill_type = "solid")
    p1.fill = PatternFill(fgColor="0079da4c", fill_type = "solid")
    q1.fill = PatternFill(fgColor="0079da4c", fill_type = "solid")
    
    #fit to the width
    col = ws.column_dimensions['A'].width = 18
    col = ws.column_dimensions['B'].width = 7
    col = ws.column_dimensions['C'].width = 13
    col = ws.column_dimensions['D'].width = 7
    col = ws.column_dimensions['E'].width = 18
    col = ws.column_dimensions['F'].width = 29
    col = ws.column_dimensions['G'].width = 36
    col = ws.column_dimensions['H'].width = 16
    col = ws.column_dimensions['I'].width = 34
    col = ws.column_dimensions['J'].width = 14
    col = ws.column_dimensions['K'].width = 18
    col = ws.column_dimensions['L'].width = 10
    col = ws.column_dimensions['M'].width = 39
    col = ws.column_dimensions['N'].width = 90
    col = ws.column_dimensions['O'].width = 44
    col = ws.column_dimensions['P'].width = 27
    col = ws.column_dimensions['Q'].width = 25
    col = ws.column_dimensions['R'].width = 20
    
    #Heigh of the header row
    ws.row_dimensions[1].height = 30
    
    #Autocomplete formul writing the formula in each cell
    starter = 0
    i = 1
    for cell in ws['N']:
        if starter == 0:
            pass
        else:
            #Adding suggestions based on the response
            exc_formula = '=IF(M{}="Línea Entregada-Enviada (Envio Completo)","Por favor actualizar información de envío / No. de envío / Comprobante de entrega en la columna Q",IF(M{}="Se Mantiene la Fecha de Entrega Acordada","Por favor si es necesario, agregue comentarios en la columna O",IF(M{}="Nueva Fecha de Entrega","Por favor confirmar nueva fecha en la columna P",IF(M{}="Orden de Compra No Recibida","Por favor si es necesario, agregue comentarios en la columna O",IF(M{}="Pagos Pendientes","Por favor específique la razón en la columna O",IF(M{}="Linea Necesita ser Cancelada","Por favor específique la razón en la columna O",IF(M{}="Línea Necesita Ser Modificada","Por favor específique los cambios requeridos en la columna O", IF(M{}="Material Listo Para Ser Recogido","Por favor envie los siguientes documentos : Packing slip / factura comercial / Prueba de Entrega", " "))))))))'.format(i,i,i,i,i,i,i,i)
            cell.value = '{}'.format(exc_formula) 
        starter+=1
        i+=1

    #Protecting the sheet
    #ws.protection.sheet = True
    #ws.protection.password = 'CS2021'
    
    #Cells to unlock
    c_unlock = ['M', 'O', 'P', 'Q', 'R']
    
    #Unlocking needed cells
    for col in c_unlock:
        starter = 0
        for cell in ws[col]:
            if starter == 0:
                pass
            else:
                cell.protection = Protection(locked=False)
            starter+=1
    
    dp_list = [
        "Línea Entregada-Enviada (Envio Completo)",
        "Se Mantiene la Fecha de Entrega Acordada",
        "Nueva Fecha de Entrega",
        "Orden de Compra No Recibida",
        "Pagos Pendientes",
        "Linea Necesita ser Cancelada",
        "Línea Necesita Ser Modificada",
        "Material Listo Para Ser Recogido"
            ]
    #Loop to write the list in a given XBF cell
    j = 1
    for v in dp_list:
        i = ws['XBF{}'.format(j)]
        i.value = "{}".format(v)
        i.font = Font(color="ffffff")
        j = j + 1
    
    dt = DataValidation(type="list", formula1='$XBF$1:$XBF$10', allow_blank=False)
    ws.add_data_validation(dt)
    
    #Adding dropdown list to the cell
    dt.add('M2:M{}'.format(l))
    
    #Priority coloration
    starter = 0
    for cell in ws['L']:
        if starter == 0:
            pass
        else:
            if cell.value == 'Medium':
                #Yellow
                cell.fill = PatternFill(fgColor="00ffee97", fill_type = "solid")
                cell.font = Font(color="00a55127")
                
            elif cell.value == 'High':
                #Red
                cell.fill = PatternFill(fgColor="00ffc1cc", fill_type = "solid")
                cell.font = Font(color="00aa004f")
                
            elif cell.value == 'Low':
                #Red
                cell.fill = PatternFill(fgColor="00baffce", fill_type = "solid")
                cell.font = Font(color="00006800")
        starter+=1
    
    wb.save(filename=ruta)

path = 'C:/Development/Automation-tools/SC-CUSBot'#'F:/Development/Automation-tools/SC-CUSBot'

#Reading supplier Language Table
supp_lang = pd.read_excel('{}/PlantContactList/Leg_4.xlsx'.format(path), sheet_name='SUP_LANG', engine='openpyxl')



#from hdbcli import dbapiGive
from hdbcli import dbapi
connection = dbapi.connect(address="sapw1pdb00.dir.slb.com",port=30015, user="LABOT", password="kC-mcLArs8b3E")
#connection = pyhdb.connect(host="sapw1pdb00.dir.slb.com",port=30015, user="LABOT",password="kC-mcLArs8b3E")
cursor = connection.cursor()
query="SELECT EBELN AS PO_Num, EBELP AS PO_Line, TXZ01 AS Description, NETWR AS Value_USD, NETWR_USD AS Value_USD, TO_CHAR(SLFDT,'MM/dd/yyyy') AS Initial_SPD, "
query= query + "TO_CHAR(EINDT,'MM/dd/yyyy') AS Current_SPD,VEND_NAME1 AS Supplier_Name, CDOC_USNM_NAME_TEXT_ITEM AS Assigned_Customer_Service_Agent,BEDNR AS Tracking_Number, "
query= query + "PLNT_NAME1 AS Plant_name,SOTX_TDLINE_F48 AS Action_ ,ERNAM AS PO_Creted_BY,ERNAM_1 AS PR_Created_By, MENGE, PLNT_NAME1, BSART, PPRO_LIFN2_PI, UNSEZ, ZORG_SEG_LEVEL_2, MATNR, VEND_LAND1, Level1Category, CC_SLB_VENDOR_CATEGORY, IDNLF, VEND_SMTP_ADDR, PPRO_LIFN2_OA, MAIN_VENDOR_ID, PURCHASE_ORDER_CONFIRMATION_TYPE, OA_Vendor_Name, UNSEZ "
query= query + "FROM \"_SYS_BIC\".\"slb.bi.sup.sdi/SUP_STG_PO_END_TO_END_INTEGRATION\" "
query= query + "WHERE STG_CURRENT_FLAG=1 AND CM_QTY_DELIVER_LEFT <> 0 "
query= query + "AND BEDAT > '20180101' "
query= query + "AND UPPER(LOEKZ) <> UPPER('L') "# Add S to this filter
query= query + "AND SOTX_TDLINE_F48 NOT IN ('','?') "
query= query + "AND (UPPER(SOTX_TDLINE_F48) LIKE ('%CONFIRMED SUPPLIER PROMISE DATE%') OR UPPER(SOTX_TDLINE_F48) LIKE ('%PENDING SUPPLIER PROMISE DATE%') OR UPPER(SOTX_TDLINE_F48) LIKE ('%CHANGED SUPPLIER PROMISE DATE%') OR UPPER(SOTX_TDLINE_F48) LIKE ('%PENDING SUPPLIER ACKNOWLEDGEMENT%') OR UPPER(SOTX_TDLINE_F48) LIKE ('%ALREADY DELIVERED%') OR UPPER(SOTX_TDLINE_F48) LIKE ('%GOODS ARE READY FOR COLLECTION%'));"
cursor.execute(query)

MyList=(cursor.fetchall())

#Sap hana query
df = pd.DataFrame(MyList)

#Renaming the columns as expected
df = df.rename(columns={
    0:'PO Num',
    1:'PO Line',
    2:'Description',
    3:'Value USD',
    4:'Value USD 2',
    5:'Initial SPD',
    6:'Current SPD',
    7:'Supplier Name',
    8:'Last changed by',
    9:'Tracking Number',
    10:'Destination Plant',
    11:'Action Message',
    12:'Requester GIN 1',
    13:'Requester GIN 2',
    14:'Order quantity',
    15:'Plant',
    16:'PO document Type',
    17:'PI Vendor ID',
    18:'PO Reference',
    19:'Segment',
    20:'Material',
    21:'Vendor Country',
    22:'Category',
    23:'SLB Vendor Category',
    24:'Vendor Part Number',
    25:'Vendor Email Address',
    26:'OA Vendor ID',
    27:'Main Vendor ID',
    28:'Confirmation Type',
    29:'OA Vendor Name',
    30:'SWPS PO'
})


temp_df.to_excel(split_file_path, index = False)

#Filling Empty Values
df['Current SPD'] = df['Current SPD'].fillna('Not')

#Changing values to needed datatypes
df['PO Line'] = df['PO Line'].astype(int)
df['Initial SPD'] = df['Initial SPD'].astype('datetime64[ns]')

# Handling current spd
def cspd(df):
    if str(df['Current SPD']) != 'Not' and str(df['Confirmation Type']) == "AB": 
        return df['Current SPD']
    else:
        return df['Initial SPD']

df['Current SPD ok'] = df.apply(cspd, axis=1)
df['Current SPD ok'] = df['Current SPD ok'].astype('datetime64[ns]')

#Removing old current spd column
df = df.drop(['Current SPD'], axis=1)

new = df["Action Message"].str.split("_", n = 5, expand = True)
df['Uploaded Date'] = new[0]
df['Agent Assigned'] = new[1]
df['Customer Service Comment'] = new[2]
df['Complementary Comment'] = new[3]

#Adding key column to remove duplicates
df['key'] = df['PO Num'].map(str) + '_' + df['PO Line'].map(str)

#Sorting Values
df = df.sort_values(by=['Uploaded Date'], ascending=False)

#Removing duplicates by po line
df = df.drop_duplicates(subset=['key'])


#Reading CS Agent assigned
cs_agents = pd.read_excel('{}/PlantContactList/Leg_4.xlsx'.format(path), sheet_name='AGENTS_LIST', engine='openpyxl')
expeditor_list=[]



for index, row in cs_agents.iterrows():
    expeditor_list.append(row['Name'])
    expeditor_list.append(row['Email'])

    


def exp_scope(df):
    if str(df['Agent Assigned']) in expeditor_list:
        return 'scope'
    else:
        return 'not scope'
    
df['Expeditor scope'] = df.apply(exp_scope, axis=1)

#Filtering only scope columns
df = df[df['Expeditor scope'] == 'scope']

#Removing column
df = df.drop(columns=['Expeditor scope'])

comments_list =[
    'Confirmed Supplier Promise Date',
    'Pending Supplier Promise Date',
    'Changed Supplier Promise Date',
    'Pending Supplier Acknowledgement'
]

comp_comments_list = [
    'Pending POD',
    'Outbound Delivery Created'
]

special_comment = [
    'Already Delivered',
    'Goods are ready for collection'  
]

def com_scope(df):
    if str(df['Customer Service Comment']) in comments_list:
        return 'scope'
    elif str(df['Customer Service Comment']) in special_comment and str(df['Complementary Comment']) in comp_comments_list:
        return 'scope'
    else:
        return 'not scope'
df['Comments Scope'] = df.apply(com_scope, axis=1)

#Filtering only scope columns
df = df[df['Comments Scope'] == 'scope']

#Removing column
df = df.drop(columns=['Comments Scope'])

supplier = pd.read_excel('{}/PlantContactList/Leg_4.xlsx'.format(path), sheet_name='SUPP_ASSIGNATION', engine='openpyxl')

supplier = supplier.drop_duplicates(subset=('Supplier name'))
supplier = pd.DataFrame(supplier[['Supplier name']])

#Removing special characteres in supplier name
df['Supplier Name'] = df['Supplier Name'].str.replace(' /', '')
df['Supplier Name'] = df['Supplier Name'].str.replace(',', '')
df['Supplier Name'] = df['Supplier Name'].str.replace('\'', '', regex=True)

df = pd.merge(left = df, right = supplier, how = 'left', left_on='Supplier Name', right_on='Supplier name')

df['Supplier name'] = df['Supplier name'].fillna('zznotscope')

df = df[df['Supplier name'] != 'zznotscope']

#Chemical identification
def chem_id(df):
    if str(df['Category']) == 'Chemicals & Logistics':
        return 'Yes'
    else:
        return 'No'

df['Chemical?'] = df.apply(chem_id, axis=1)

def run_scope(df):
    if str(df['Customer Service Comment']) == 'Changed Supplier Promise Date':
        if df['Current SPD ok'] >= datetime.datetime.now() + datetime.timedelta(days=7):
            return 'wrong'
        elif str(df['Chemical?']) == 'Yes':
            if datetime.datetime.now() + datetime.timedelta(days=15) >= df['Current SPD ok']:
                return 'ok'
            else:
                return 'wrong'
        else:
            return 'ok'
    elif str(df['Customer Service Comment']) == 'Confirmed Supplier Promise Date':
        if df['Current SPD ok'] >= datetime.datetime.now() + datetime.timedelta(days=15):
            return 'wrong'
        else:
            return 'ok'
    else:
        return 'ok'

df['Run_Scope'] = df.apply(run_scope, axis=1)

df = df[df['Run_Scope'] == 'ok']




#Priority Column
def priority(df):
    if df['Current SPD ok'] >= datetime.datetime.now() + datetime.timedelta(days=15):
        return 'Low'
    if df['Current SPD ok'] > datetime.datetime.now() + datetime.timedelta(days=7) and df['Current SPD ok'] < datetime.datetime.now() + datetime.timedelta(days=15):
        return 'Medium'
    if df['Current SPD ok'] <= datetime.datetime.now() + datetime.timedelta(days=7):
        return 'High'

df['Priority'] = df.apply(priority, axis=1)

##Block changed
def run_col(df):
    if str(df['SLB Vendor Category']) == 'Third Party':
        return 'External'
    else:
        return 'Internal'

df['Run_col'] = df.apply(run_col, axis=1)

#Creating new dataframe with only needed columns
f_df = pd.DataFrame(df[['PO Num','SWPS PO', 'PO Line', 'Plant', 'Material', 'Vendor Part Number', 'Description', 'Order quantity', 'Supplier Name', 'Main Vendor ID', 'Current SPD ok', 'Priority', 'Chemical?', 'Run_col', 'Vendor Country','Vendor Email Address', 'Customer Service Comment', 'Complementary Comment']])

#Creating empty columns to fill the template
f_df['PO Status'] = None
f_df['PO status Action Item'] = None
f_df['Comments'] = None
f_df['New Supplier Promise Date'] = None
f_df['Tracking Number'] = None
f_df['Ship To'] = None
f_df =f_df

#Re ordering needed columns
df = f_df[['PO Num', 'PO Line', 'SWPS PO', 'Plant', 'Material', 'Vendor Part Number', 'Description', 'Order quantity', 'Supplier Name', 'Main Vendor ID','Current SPD ok', 'Priority', 'PO Status', 'PO status Action Item', 'Comments', 'New Supplier Promise Date', 'Tracking Number', 'Ship To', 'Chemical?', 'Run_col', 'Vendor Country', 'Vendor Email Address', 'Customer Service Comment', 'Complementary Comment']]

#Crosschecking the information with supplier language
supp_lang = supp_lang.drop_duplicates(subset = 'Vendor Country')
df = pd.merge(left =df, right=supp_lang, how= 'left', left_on='Vendor Country', right_on='Vendor Country')

#Filling out empty Languages
df['Language'] = df['Language'].str.replace('Portuguese', 'English')
df['Language'] = df['Language'].fillna('English')

#Creating run date column
df['Run Date'] = datetime.datetime.now()

#Removing special characteres in supplier name
df['Supplier Name'] = df['Supplier Name'].str.replace(' /', '')
df['Supplier Name'] = df['Supplier Name'].str.replace(',', '')
df['Supplier Name'] = df['Supplier Name'].str.replace('\'', '', regex=True)

#Exporting consolidated file to last path
f_path = path + '/Report/Suppliers/Internal/ES'
df.to_excel('{}/ZZL4NOT.xlsx'.format(f_path), index=False)

#Re ordering needed columns
df = df[['PO Num', 'PO Line', 'SWPS PO', 'Plant', 'Material', 'Vendor Part Number', 'Description', 'Order quantity', 'Supplier Name', 'Main Vendor ID','Current SPD ok', 'Priority', 'PO Status', 'PO status Action Item', 'Comments', 'New Supplier Promise Date', 'Tracking Number', 'Ship To', 'Chemical?', 'Run_col', 'Vendor Country', 'Vendor Email Address','Language', 'Run Date']]


#Change the format of the Supplier Promise Date
df['Current SPD ok']=pd.to_datetime(df['Current SPD ok'],
                                    format="%Y/%m/%d")
df['Current SPD ok']=pd.to_datetime(df['Current SPD ok']).dt.strftime('%m/%d/%y')



#Separating run type files
df_external = df[df['Run_col'] == 'External']
df_internal = df[df['Run_col'] == 'Internal']

#Dropping uneeded columns
df_external = df_external.drop(columns =['Chemical?', 'Run_col', 'Run Date'])
df_internal = df_internal.drop(columns =['Chemical?', 'Run_col', 'Run Date'])

col_name = 'Supplier Name'

# External Notification
## External notification English

#Filtering only ext english suppliers
df_external_en = df_external[df_external['Language'] == 'English']

df = df_external_en

df = df.rename(columns={
    'Order quantity':'Pending QTY',
    'Material':'Part Number',
    'Current SPD ok':'Supplier Promise Date'
})




#Deleting uneeded columns
df = df.drop(columns = ['Language', 'Vendor Email Address', 'Vendor Country', 'Main Vendor ID'])

#Creating f_path
f_path = path + '/Report/Suppliers/External/EN'

#Sort Values to start splitting data
df = df.sort_values(by=[col_name, 'PO Num', 'PO Line'])
df = df.reset_index(drop = True)

#Spliting gold block
vendor = pd.DataFrame(df)
delete = []
a = 0 #Rest of rows afer iterations
b = len(vendor) #Total of rouws in the CAM OOR excel file

for i in range(1, len(vendor) + 1):
    if i == b:

        temp_df = pd.DataFrame(vendor.loc[:i-1])
        split_file_path = '{}/{}.xlsx'.format(f_path,vendor.loc[i-1][col_name].replace(' /', ''))
        temp_df.to_excel(split_file_path, index = False)
        #Styles application
        excel_manipulation(split_file_path)

        for index, rows in vendor.loc[:i-1].iterrows():
            delete.append(index)
        if DEBUG:
            print(delete[a:i])
        vendor = pd.DataFrame(vendor.drop(delete[a:i]))
        a = a + (len(temp_df))
        break

    if vendor.loc[i][col_name] == vendor.loc[i-1][col_name]:
        if DEBUG:
            print(i)
        x= 0
    else:

        temp_df = pd.DataFrame(vendor.loc[:i-1])
        split_file_path = '{}/{}.xlsx'.format(f_path,vendor.loc[i-1][col_name])
        temp_df.to_excel(split_file_path, index = False, engine='openpyxl')
        #Styles application
        excel_manipulation(split_file_path)

        for index, rows in vendor.loc[:i-1].iterrows():
            delete.append(index)
        if DEBUG:
            print(delete[a:i])
        vendor = pd.DataFrame(vendor.drop(delete[a:i]))
        a = a + (len(temp_df))

## External notification Spanish

df = df_external[df_external['Language'] == 'Spanish']

#Deleting uneeded columns
df = df.drop(columns = ['Language', 'Vendor Email Address', 'Vendor Country'])
df = df.rename(columns={
    "PO Num": "Orden de Compra",
    "PO Line": "Línea",
    "SWPS PO": "Orden SWPS",
    "Plant": "Planta",
    "Material": "Número de Parte",
    "Vendor Part Number": "Número de Parte Proveedor",
    "Description": "Descripción",
    "Order quantity": "Cant. Pendiente",
    "Supplier Name": "Proveedor",
    "Current SPD ok": "Fecha Prometida",
    "Priority": "Prioridad",
    "PO Status": "Estado OC",
    "PO status Action Item": "Acción requerida para estado OC",
    "Comments": "Comentarios",
    "New Supplier Promise Date": "Nueva Fecha Prometida",
    "Tracking Number": "Número de Seguimiento",
    "Ship To": "Dirección de Envío"
})

col_name = 'Proveedor'

#Creating f_path
f_path = path + '/Report/Suppliers/External/ES'

#Sort Values to start splitting data
df = df.sort_values(by=[col_name, 'Orden de Compra','Línea'])
df = df.reset_index(drop = True)

#Spliting gold block
vendor = pd.DataFrame(df)
delete = []
a = 0 #Rest of rows afer iterations
b = len(vendor) #Total of rouws in the l4 file

for i in range(1, len(vendor) + 1):
    if i == b:

        temp_df = pd.DataFrame(vendor.loc[:i-1])
        split_file_path = '{}/{}.xlsx'.format(f_path,vendor.loc[i-1][col_name])
        temp_df.to_excel(split_file_path, index = False)
        #Styles application
        excel_manipulation_es(split_file_path)

        for index, rows in vendor.loc[:i-1].iterrows():
            delete.append(index)
        if DEBUG:
            print(delete[a:i])
        vendor = pd.DataFrame(vendor.drop(delete[a:i]))
        a = a + (len(temp_df))
        break

    if vendor.loc[i][col_name] == vendor.loc[i-1][col_name]:
        if DEBUG:
            print(i)
        x= 0
    else:

        temp_df = pd.DataFrame(vendor.loc[:i-1])
        split_file_path = '{}/{}.xlsx'.format(f_path,vendor.loc[i-1][col_name])
        temp_df.to_excel(split_file_path, index = False)
        #Styles application
        excel_manipulation_es(split_file_path)

        for index, rows in vendor.loc[:i-1].iterrows():
            delete.append(index)
        if DEBUG:
            print(delete[a:i])
        vendor = pd.DataFrame(vendor.drop(delete[a:i]))
        a = a + (len(temp_df))

col_name = 'Supplier Name'

# Internal Notification

## Internal English

df = df_internal[df_internal['Language'] == 'English']

df = df.rename(columns={
    'Order quantity':'Pending QTY',
    'Material':'Part Number',
    'Current SPD ok':'Supplier Promise Date'
})

#Deleting uneeded columns
df = df.drop(columns = ['Language', 'Vendor Email Address', 'Vendor Country', 'Main Vendor ID'])

#Creating f_path
f_path = path + '/Report/Suppliers/Internal/EN'

#Sort Values to start splitting data
df = df.sort_values(by=[col_name, 'PO Num','PO Line'])
df = df.reset_index(drop = True)

#Spliting gold block
vendor = pd.DataFrame(df)
delete = []
a = 0 #Rest of rows afer iterations
b = len(vendor) #Total of rouws in the CAM OOR excel file

for i in range(1, len(vendor) + 1):
    if i == b:

        temp_df = pd.DataFrame(vendor.loc[:i-1])
        split_file_path = '{}/{}.xlsx'.format(f_path,vendor.loc[i-1][col_name])
        temp_df.to_excel(split_file_path, index = False)
        #Styles application
        excel_manipulation(split_file_path)

        for index, rows in vendor.loc[:i-1].iterrows():
            delete.append(index)
        if DEBUG:
            print(delete[a:i])
        vendor = pd.DataFrame(vendor.drop(delete[a:i]))
        a = a + (len(temp_df))
        break

    if vendor.loc[i][col_name] == vendor.loc[i-1][col_name]:
        if DEBUG:
            print(i)
        x= 0
    else:

        temp_df = pd.DataFrame(vendor.loc[:i-1])
        split_file_path = '{}/{}.xlsx'.format(f_path,vendor.loc[i-1][col_name])
        temp_df.to_excel(split_file_path, index = False)
        #Styles application
        excel_manipulation(split_file_path)

        for index, rows in vendor.loc[:i-1].iterrows():
            delete.append(index)
        if DEBUG:
            print(delete[a:i])
        vendor = pd.DataFrame(vendor.drop(delete[a:i]))
        a = a + (len(temp_df))

# Internal Spanish

col_name = 'Proveedor'
df = df_internal[df_internal['Language'] == 'Spanish']

#Deleting uneeded columns
df = df.drop(columns = ['Language', 'Vendor Email Address', 'Vendor Country'])
df = df.rename(columns={
    "PO Num": "Orden de Compra",
    "PO Line": "Línea",
    "SWPS PO": "Orden SWPS",
    "Plant": "Planta",
    "Material": "Número de Parte",
    "Vendor Part Number": "Número de Parte Proveedor",
    "Description": "Descripción",
    "Order quantity": "Cant. Pendiente",
    "Supplier Name": "Proveedor",
    "Current SPD ok": "Fecha Prometida",
    "Priority": "Prioridad",
    "PO Status": "Estado OC",
    "PO status Action Item": "Acción requerida para estado OC",
    "Comments": "Comentarios",
    "New Supplier Promise Date": "Nueva Fecha Prometida",
    "Tracking Number": "Número de Seguimiento",
    "Ship To": "Dirección de Envío"
})

#Creating f_path
f_path = path + '/Report/Suppliers/Internal/ES'

#Sort Values to start splitting data
df = df.sort_values(by=[col_name,'Orden de Compra', 'Línea'])
df = df.reset_index(drop = True)

#Spliting gold block
vendor = pd.DataFrame(df)
delete = []
a = 0 #Rest of rows afer iterations
b = len(vendor) #Total of rouws in the CAM OOR excel file

for i in range(1, len(vendor) + 1):
    if i == b:

        temp_df = pd.DataFrame(vendor.loc[:i-1])
        split_file_path = '{}/{}.xlsx'.format(f_path,vendor.loc[i-1][col_name])
        temp_df.to_excel(split_file_path, index = False)
        #Styles application
        excel_manipulation_es(split_file_path)

        for index, rows in vendor.loc[:i-1].iterrows():
            delete.append(index)
        if DEBUG:
            print(delete[a:i])
        vendor = pd.DataFrame(vendor.drop(delete[a:i]))
        a = a + (len(temp_df))
        break

    if vendor.loc[i][col_name] == vendor.loc[i-1][col_name]:
        if DEBUG:
            print(i)
        x= 0
    else:

        temp_df = pd.DataFrame(vendor.loc[:i-1])
        split_file_path = '{}/{}.xlsx'.format(f_path,vendor.loc[i-1][col_name])
        temp_df.to_excel(split_file_path, index = False)
        #Styles application
        excel_manipulation_es(split_file_path)

        for index, rows in vendor.loc[:i-1].iterrows():
            delete.append(index)
        if DEBUG:
            print(delete[a:i])
        vendor = pd.DataFrame(vendor.drop(delete[a:i]))
        a = a + (len(temp_df))

print('Complete')
# Out:
# Complete
