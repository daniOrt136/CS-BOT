# %%
def excel_manipulation(ruta):
    wb = xl.load_workbook(ruta)
    ws = wb.active
    
    global temp_df
    l = len(temp_df)+1

    #Changing Zoom to a sheet
    ws.sheet_view.zoomScale = 100

    #Defining the border style
    thin_border = Border(left=Side(style='thin'),
                         right=Side(style='thin'),
                         top=Side(style='thin'),
                         bottom=Side(style='thin')                    
                        )

    #applying borders to all table
    for row in ws.iter_rows():
            for cell in row:
                cell.alignment = Alignment(wrapText=False)
                cell.font = Font(name='Calibri', size=11)
                cell.border = thin_border
                cell.alignment = Alignment(vertical='center', horizontal='center')
    #modifing the header style
    for i in ws[1]:
        i.font = Font(color="00000000", name='Calibri', size=12, bold = True)

    a1 = ws['A1']
    b1 = ws['B1']
    c1 = ws['C1']
    d1 = ws['D1']
    e1 = ws['E1']
    f1 = ws['F1']
    g1 = ws['G1']
    h1 = ws['H1']
    i1 = ws['I1']
    j1 = ws['J1']
    k1 = ws['K1']
    l1 = ws['L1']
    m1 = ws['M1']
    n1 = ws['N1']
    o1 = ws['O1']
    p1 = ws['P1']
    q1 = ws['Q1']
    r1 = ws['R1']
    
    #Clean blue
    a1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    b1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    c1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    d1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    e1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    f1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    g1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    h1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    i1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    j1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    k1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    l1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    m1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")
    o1.fill = PatternFill(fgColor="00b3c4e9", fill_type = "solid")

    
    #Green
    n1.fill = PatternFill(fgColor="0079da4c", fill_type = "solid")
    p1.fill = PatternFill(fgColor="0079da4c", fill_type = "solid")
    q1.fill = PatternFill(fgColor="0079da4c", fill_type = "solid")
    r1.fill = PatternFill(fgColor="0079da4c", fill_type = "solid")
    
    #fit to the width
    col = ws.column_dimensions['A'].width = 20
    col = ws.column_dimensions['B'].width = 10
    col = ws.column_dimensions['C'].width = 8
    col = ws.column_dimensions['D'].width = 8
    col = ws.column_dimensions['E'].width = 15
    col = ws.column_dimensions['F'].width = 18
    col = ws.column_dimensions['G'].width = 35
    col = ws.column_dimensions['H'].width = 10
    col = ws.column_dimensions['I'].width = 12
    col = ws.column_dimensions['J'].width = 15
    col = ws.column_dimensions['K'].width = 25
    col = ws.column_dimensions['L'].width = 25
    col = ws.column_dimensions['M'].width = 15
    col = ws.column_dimensions['N'].width = 50
    col = ws.column_dimensions['O'].width = 44
    col = ws.column_dimensions['P'].width = 40
    col = ws.column_dimensions['Q'].width = 35
    col = ws.column_dimensions['R'].width = 30 

    
    #Heigh of the header row
    ws.row_dimensions[1].height = 30
    
    #Autocomplete formul writing the formula in each cell
    starter = 0
    i = 1
    for cell in ws['O']:
        if starter == 0:
            pass
        else:
            #Adding suggestions based on the response
            exc_formula = '=IF(N{}="Line Item Delivered-Shipped (Complete Shipment)","Please provide Shipping details / Tracking # / POD in column R",IF(N{}="Original Delivery Date Remains","Please Provide comments if they are necessary in column P",IF(N{}="New Delivery Date","Please Provide new date in column Q",IF(N{}="PO Not Received","Please Provide comments if they are necessary in column P",IF(N{}="Payment Issues","Please Provide reason why in column P",IF(N{}="Line Item Needs to be Cancelled","Please Provide reason why in column P",IF(N{}="Line Item Needs to be Modified","Please Specify changes needed in column P",IF(N{}="Material Ready for Pick Up","Please send Delivery Documents Packing Slip / Commercial Invoice / Material Safety Data",""))))))))'.format(i,i,i,i,i,i,i,i)
            cell.value = '{}'.format(exc_formula) 
        starter+=1
        i+=1
    
    #Dropdown List
    dv = DataValidation(type="list", formula1='"Line Item Delivered-Shipped (Complete Shipment), Original Delivery Date Remains, New Delivery Date, PO Not Received, Payment Issues, Line Item Needs to be Cancelled, Line Item Needs to be Modified, Material Ready for Pick Up"', allow_blank=False)
    ws.add_data_validation(dv)
    
    #Adding dropdown list to the cell
    dv.add('N2:N{}'.format(l))
    
    #Protecting the sheet
    ws.protection.sheet = True
    ws.protection.password = 'CS2021'
    
    #Cells to unlock
    c_unlock = ['N', 'P', 'Q', 'R']
    
    #Unlocking needed cells
    for col in c_unlock:
        starter = 0
        for cell in ws[col]:
            if starter == 0:
                pass
            else:
                cell.protection = Protection(locked=False)
            starter+=1
            
    #Data validation of column Q of new date
    ds = DataValidation(type="custom",formula1='=AND(ISNUMBER(Q2),LEFT(CELL("format",Q2),1)="D")')
    ws.add_data_validation(ds)        
            
    ds.add('Q2:Q{}'.format(l))

    #Format for Column P of new del date
    starter = 0
    for cell in ws['Q']:
        if starter == 0:
            pass
        else:
            cell.protection = Protection(locked=False)
            cell.number_format = "mm/dd/yyyy"
        starter+=1
    

    
    #Priority coloration
    starter = 0
    for cell in ws['M']:
        if starter == 0:
            pass
        else:
            if cell.value == 'Medium':
                #Yellow
                cell.fill = PatternFill(fgColor="00ffee97", fill_type = "solid")
                cell.font = Font(color="00a55127")
                
            elif cell.value == 'High':
                #Red
                cell.fill = PatternFill(fgColor="00ffc1cc", fill_type = "solid")
                cell.font = Font(color="00aa004f")
                
            elif cell.value == 'Low':
                #Red
                cell.fill = PatternFill(fgColor="00baffce", fill_type = "solid")
                cell.font = Font(color="00006800")
        starter+=1
    
    wb.save(filename=ruta)

## Spanish template design function

#import hdbcli
import pyhdb
import datetime
from datetime import timedelta
import pandas as pd
from openpyxl.styles import Font, Color, PatternFill, Protection, Alignment, Border, Side
from openpyxl.worksheet.datavalidation import DataValidation
import os
import openpyxl as xl
import pyodbc
import math
from pathlib import Path
import linecache

DEBUG = False

## English template design function

path = 'C:/Development/Automation-tools/SC-CUSBot'#'F:/Development/Automation-tools/SC-CUSBot'

#Reading supplier Language Table
taxonomy = pd.read_excel('{}/Report/Taxonomy.xlsx'.format(path), engine='openpyxl', header=None, names=['Commodity','Product'])
SupList = pd.read_csv('{}/Report/SupplierList.csv'.format(path),delimiter=',', converters={'Supplier_ID':str})
SupList1 = pd.read_csv('{}/Report/SupplierList1.csv'.format(path),delimiter=',', converters={'Supplier_ID':str})
SupList=pd.concat([SupList,SupList1])
SupList=SupList.drop_duplicates(subset='Supplier_ID')
supListExc= SupList[['Supplier_ID', 'Agent','Supplier_Contact', 'Supplier_Name']]
supListExc.to_excel('{}/Report/Suppliers/SupplierList.xlsx'.format(path), index=False)
hub = linecache.getline('{}/BotScripts/hub.txt'.format(path), 1)          
#Todays Information
today = pd.datetime.now()
year,week_num,day_of_week = today.isocalendar()


##Bringing the table with the latest send to the supplier:

driver = 'SQL Server'
server='azr2680prdsql05.earaa2680.azr.slb.com'
database='sc-config'
Driver='ODBC Driver 17 for SQL Server'
username='scadmin'
password='Sc@dmin01'

cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)

sql = "SELECT sd.SUPPLIER_ID, sd.SUPPLIER, sd.CREATION_DATE FROM (SELECT  SUPPLIER_ID, SUPPLIER, CREATION_DATE, RUN_NAME,  ROW_NUMBER() OVER(PARTITION BY SUPPLIER_ID ORDER BY CREATION_DATE DESC) toprow FROM dbo.T_SCCUSBOT_LOG ) sd   WHERE sd.toprow =1 and sd.RUN_NAME='L4NGlobal' ;"

sql_db=pd.read_sql(sql,cnxn)


SupList=pd.merge(left =SupList, right=sql_db, how= 'left', left_on='Supplier_ID',right_on='SUPPLIER_ID')


SupList['CREATION_DATE'] = pd.to_datetime(SupList['CREATION_DATE'])
SupList['LastRunWeek']=SupList['CREATION_DATE'].dt.week
SupList['WeekNextRun']=SupList['LastRunWeek']+SupList['Frecuency']
SupList['WeekNextRun']=SupList['WeekNextRun'].fillna(week_num)
SupList=SupList[SupList['WeekNextRun']==week_num]


supQuery =SupList['Supplier_ID'].to_string(index=False).split('\n')
supQuery = [x.strip(' ') for x in supQuery]
supString ="('"+ "', '".join(supQuery)+"')"

#from hdbcli import dbapiGive
from hdbcli import dbapi
connection = dbapi.connect(address="sapw1pdb00.dir.slb.com",port=30015, user="LABOT", password="kC-mcLArs8b3E")
#connection = pyhdb.connect(host="sapw1pdb00.dir.slb.com",port=30015, user="LABOT",password="kC-mcLArs8b3E")
cursor = connection.cursor()
query="SELECT EBELN AS PO_Num, EBELP AS PO_Line, TXZ01 AS Description, NETWR AS Value_USD, TO_CHAR(SLFDT,'MM/dd/yyyy') AS Initial_SPD, "
query= query + "TO_CHAR(EINDT,'MM/dd/yyyy') AS Current_SPD,VEND_NAME1 AS Supplier_Name, CDOC_USNM_NAME_TEXT_ITEM AS Assigned_Customer_Service_Agent,BEDNR AS Tracking_Number, "
query= query + "PLNT_NAME1 AS Plant_name,SOTX_TDLINE_F48 AS Action_ , CM_QTY_DELIVER_LEFT, WERKS, BSART, PPRO_LIFN2_PI, UNSEZ, ZORG_SEG_LEVEL_2, MATNR, VEND_LAND1, Level1Category, CC_SLB_VENDOR_CATEGORY, IDNLF, VEND_SMTP_ADDR, PPRO_LIFN2_OA, MAIN_VENDOR_ID, PURCHASE_ORDER_CONFIRMATION_TYPE, UNSEZ, MDUI_MSEH3, EKKO_INCO1, TO_CHAR(EINDT_1,'MM/dd/yyyy') AS Req_Del_Date, TO_CHAR(ZZPERF_DATE,'MM/dd/yyyy') AS Performance_Date, GOODS_RECEIPTS, EKGRP, MATKL,CC_PO_RELEASE_INDICATOR,STG_CURRENT_FLAG,BSART,CM_QTY_DELIVER_LEFT,CC_PO_ITEM_DELETED_FLAG "
query= query + "FROM \"_SYS_BIC\".\"slb.bi.sup.sdi/SUP_STG_PO_END_TO_END_INTEGRATION\" "
query= query + "WHERE STG_CURRENT_FLAG=1 AND CM_QTY_DELIVER_LEFT <> 0 AND MAIN_VENDOR_ID IN " + supString
query= query + " AND STG_DELETION_FLAG <> 'D' AND CC_PO_ITEM_DELETED_FLAG='N' AND BSART IN ('ZATF','ZNB','ZCON') "
query= query + "AND GOODS_RECEIPTS = 'OPEN PO' AND CC_PO_RELEASE_INDICATOR= 'Approved' "
cursor.execute(query)

## The query already have the filters of:
#Qty to deliver greater than 0, Goods receipt is Open PO, PO Released indicator in Approved and the filters of the power bi query.

MyList=(cursor.fetchall())

#Sap hana query
df = pd.DataFrame(MyList)

#Renaming the columns as expected
df = df.rename(columns={
    0:'PO Num',
    1:'PO Line',
    2:'Description',
    3:'Value USD',
    4:'Initial SPD',
    5:'Supplier Promise Date',
    6:'Supplier Name',
    7:'Last changed by',
    8:'Tracking Number',
    9:'Destination Plant',
    10:'Action Message',
    11:'Pending QTY',
    12:'Plant',
    13:'PO document Type',
    14:'PI Vendor ID',
    15:'PO Reference',
    16:'Segment',
    17:'Part Number',
    18:'Vendor Country',
    19:'Category',
    20:'Vendor Category',
    21:'Vendor Part Number',
    22:'Vendor Email Address',
    23:'OA Vendor ID',
    24:'Main Vendor ID',
    25:'Confirmation Type',
    26:'SWPS PO',
    27:'UOM',
    28:'Incoterm',
    29:'Supplier Requested Date',
    30:'Performance Date',
    31:'Goods Receipt',
    32:'PGroup',
    33:'Commodity'
})
# Out:
# C:\Users\DOrtiz10\AppData\Local\Temp/ipykernel_16212/1936799376.py:206: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   today = pd.datetime.now()
# C:\Users\DOrtiz10\AppData\Local\Temp/ipykernel_16212/1936799376.py:230: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   SupList['LastRunWeek']=SupList['CREATION_DATE'].dt.week

# %%
print('step1')
if len(df)>1:

    df['PO Line'] = df['PO Line'].astype(int).astype(str)

    today = pd.datetime.now()
    df['Supplier Promise Date'] = pd.to_datetime(df['Supplier Promise Date'])
    df['Supplier Requested Date'] = pd.to_datetime(df['Supplier Requested Date'])
    df["SPD DateDiff"] = (df['Supplier Promise Date']-today).dt.days

    ## Filteringhere the filters that were added in the dashboard

    #Filter for the orders that are flagged as already delivered in the action message

    includedPgroup=['A01','A02','A03','A04','A05','A06','B01','C01','C02','C03','C04','C05','D01','D02','D03','D04']
    def scope(df):
        if 'ALREADY DELIVERED' not in str(df['Action Message']).upper() and (df['PO document Type'] in ['ZATF','ZNB','ZCON'])\
        and df['Destination Plant'] not in ['Rosharon Completions Center','Houston Product Center'] \
        and df['PGroup'] in includedPgroup and df['Vendor Category']=='Third Party' and (df["SPD DateDiff"]<=15 or pd.isna(df['Supplier Promise Date'])) :
            return 'Scope'
        else:
            return 'Not Scope'
    df['Scope']=df.apply(scope,axis=1)
    df=df[df['Scope']=='Scope']


    df = pd.merge(left =df, right=taxonomy, how= 'left', on='Commodity')
    df = df[df['Product']=='Product']
    

    #Merging the main report with the supplier contact list and with the pivot of latest sent
    dff=pd.merge(left=df, right=SupList, how= 'left', left_on='Main Vendor ID',right_on='Supplier_ID')
    dff=dff[~pd.isna(dff['Supplier_ID'])]
    dff=dff[dff['Bot_Active']=="Yes"]
    dff=dff[dff['Hub']==hub.strip()]
    if len(dff)>1:
        def cspd(dff):
            if pd.isna(dff['Supplier Promise Date']): 
                return dff['Supplier Requested Date']
            else:
                return dff['Supplier Promise Date']


        dff['Supplier promise Date'] = dff.apply(cspd, axis=1)
       # dff['Supplier promise Date'] = dff['Supplier promise Date'].astype('datetime64[ns]')



        #Priority Column
        def priority(dff):
            if dff['Supplier promise Date'] >= datetime.datetime.now() + datetime.timedelta(days=15):
                return 'Low'
            if dff['Supplier promise Date'] > datetime.datetime.now() + datetime.timedelta(days=7) and dff['Supplier promise Date'] < datetime.datetime.now() + datetime.timedelta(days=15):
                return 'Medium'
            if dff['Supplier promise Date'] <= datetime.datetime.now() + datetime.timedelta(days=7):
                return 'High'

        dff['Priority'] = dff.apply(priority, axis=1)
        df['Supplier Promise Date'].dt.strftime('%m/%d/%y')



        #Creating new dataframe with only needed columns
        f_df = pd.DataFrame(dff[['Main Vendor ID','Supplier Name', 'PO Num', 'PO Line' ,'Plant', 'Part Number', 'Vendor Part Number', 'Description', 'UOM', 'Incoterm', 'Pending QTY', 'Performance Date', 'Supplier promise Date', 'Priority']])

        #Creating empty columns to fill the template
        f_df['PO Status'] = None
        f_df['PO status Action Item'] = None
        f_df['Comments'] = None
        f_df['New Supplier Promise Date (mm/dd/yyyy)'] = None
        f_df['Courrier / Tracking Number'] = None



        tempSuccess=""
        dbInsert=pd.DataFrame(columns=['OA Vendor','Success Insert'])
        x=0
        dfGrouped=f_df.groupby('Main Vendor ID')
        fpath=path+ '/Report/Leg4'
        for name, group in dfGrouped:
            #split and creation of the file
            temp_df= group.sort_values(by=['Priority', 'PO Num'])
            temp_df=temp_df.drop(columns={'Main Vendor ID',})
            split_file_path = '{}/{}.xlsx'.format(fpath, name)
            temp_df.to_excel(split_file_path,index=False)
            excel_manipulation(split_file_path)


            #Creating the records for each supplier
            numVal=len(group)
            itera=math.ceil(numVal/1000)
            group=group.applymap(str)
            group.reset_index(inplace=True)
            for j in range(1,itera+1):
                query="INSERT INTO ""dbo"".""T_SCCUSBOT_LOG"" ( PO_LINE, PLANT, PRIORITY , SUPPLIER_ID, CREATION_DATE, STATUS ,RUN_NAME) VALUES "
                rowNum=0
                tempSuccess1=""
                if j == (itera):
                    x=len(group)-((j-1)*1000)
                else:
                    x=1000
                for m in range(0,x):
                    i=m+(((j-1)*1000))
                    if rowNum==0:
                        tempSuccess1=query + "('" + str(group['PO Num'][i]) + "_"+ str(int(group['PO Line'][i]))+ "',"+ "'" + str(group['Plant'][i]) + "'," + "'" + group['Priority'][i] + "',"  + "'" + name + "'," + "CONVERT(date, GETDATE()),"  + "'Success'," + "'L4NTest'),"   
                    else:
                        tempSuccess1=tempSuccess1  + "('" + str(group['PO Num'][i]) + "_"+ str(int(group['PO Line'][i]))+ "',"+ "'" + str(group['Plant'][i]) + "'," + "'" + group['Priority'][i] + "'," + "'" + name + "'," + "CONVERT(date, GETDATE()),"  + "'Success'," + "'L4NTest'),"   
                    rowNum+=1
                tempSuccess=tempSuccess1[:len(tempSuccess1)-1].replace("'None'", "NULL").replace("'NaT'", "NULL").replace("'nan'", "NULL")
                dbInsert.loc[len(dbInsert.index)]=[name, tempSuccess]



        f_df.to_excel('{}/Report/ZZCUSBOTL4.xlsx'.format(path),index=False)



        driver = 'SQL Server'
        server='azr2680prdsql05.earaa2680.azr.slb.com'
        database='sc-config'
        Driver='ODBC Driver 17 for SQL Server'
        username='scadmin'
        password='Sc@dmin01'

        cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
        cursor = cnxn.cursor()

        dbfailures=pd.DataFrame(columns=['OA Vendor','Insert'])


        from datetime import datetime
        for i, row in dbInsert.iterrows():
            try:
                cursor.execute(row['Success Insert'])
            except:
                dbfailures.loc[len(dbfailures.index)]=[row['OA Vendor'], row['Success Insert']]


        cursor.commit()

        if len(dbfailures)>1:
            dbfailures.to_excel('{}/InsertFailures.xlsx'.format(path))

        print('Complete')

    else:
        print('No lines')
else:
    print('No lines')
# Out:
# step1
# C:\Users\DOrtiz10\AppData\Local\Temp/ipykernel_16212/2334097883.py:6: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   today = pd.datetime.now()
# Complete

# %%
len(dff)
# Out:
# 344

# %%
 df['Supplier Promise Date'].dt.strftime('%m/%d/%y')
# Out:
# 1              NaN
# 2              NaN
# 3              NaN
# 5              NaN
# 7         11/04/22
#             ...
# 132045         NaN
# 132046         NaN
# 132047         NaN
# 132048         NaN
# 132049         NaN
# Name: Supplier Promise Date, Length: 91992, dtype: object

# %%
dff['Supplier promise Date']=dff['Supplier promise Date'].dt.strftime('%m/%d/%y')
dff['Supplier promise Date']
# Out:
# 91       10/14/22
# 583      10/14/22
# 937      10/10/22
# 1040     10/14/22
# 1126     10/10/22
#            ...
# 73029    08/12/22
# 73916    07/05/22
# 75339    08/02/22
# 75340    08/02/22
# 75345    08/02/22
# Name: Supplier promise Date, Length: 344, dtype: object

# %% [markdown]
# ## Filtering
# here the filters that were added in the dashboard
